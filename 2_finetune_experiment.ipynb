# %% [markdown]
# <a href="https://colab.research.google.com/github/ocean8800v/manuscript-pipeline/blob/main/2_finetune_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================
# 🔧 Setup Python 3.11 + TabPFN env in Colab
# ==============================

# 1. Install Conda (via condacolab)
# !pip install -q condacolab
import condacolab
condacolab.install()

# 2. Create a new Conda environment with Python 3.11
# !conda create -n py311 python=3.11.13 -y -c conda-forge

# 3. Install PyTorch (2.1.0 + cu121) and all required dependencies inside py311
# !conda run -n py311 pip install \
    pandas==2.2.2 \
    scikit-learn==1.5.2 \
    scipy==1.15.3 \
    tabpfn==2.0.9 \
    ruff==0.12.6 \
    pynvml==12.0.0 \
    wandb==0.21.0 \
    schedulefree==1.4.1 \
    seaborn==0.12.2 \
    tqdm==4.67.1 \
    pyyaml==6.0.2\
    numpy==1.24.1
# !conda run -n py311 pip install torch==2.1.0 torchvision==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu121

# !conda run -n py311 python -c "import sys, torch, sklearn, numpy, scipy, tabpfn, pandas; \
print(f'Python: {sys.version}'); \
print(f'Torch: {torch.__version__}'); \
print(f'scikit-learn: {sklearn.__version__}'); \
print(f'Numpy: {numpy.__version__}'); \
print(f'Pandas: {pandas.__version__}'); \
print(f'SciPy: {scipy.__version__}'); \
print(f'TabPFN: {tabpfn.__version__}')"

# %%
from google.colab import drive
drive.mount('/content/drive')
# !git clone https://github.com/ocean8800v/cross-national-cognitive-ai.git

# %%
# %%writefile /content/finetune_experiment.py
import os, subprocess, sys
import pandas as pd
from sklearn.model_selection import train_test_split

sys.path.append('/content/manuscript-pipeline/finetune_experiment')
from finetuning_scripts.finetune_tabpfn_main import fine_tune_tabpfn

import torch
sys.stdout.reconfigure(line_buffering=True)  # ensure real-time log flushing

subprocess.run(["nvidia-smi"], check=False)
if not torch.cuda.is_available():
    raise SystemError('GPU device not found. For fast training, please enable GPU.')

torch.cuda.empty_cache()
torch.backends.cuda.enable_flash_sdp(True)
torch.backends.cuda.enable_mem_efficient_sdp(False)
torch.backends.cuda.enable_math_sdp(False)

# ========== Fine-tuning Experiment ==========
predictors = [
    "asinmiss", "logresvar", "mdistance", "gnorm", "lz", "u3", "extreme",
    "language", "country", "scale", "id"
]

target_col = 'health_vs_mci_vs_dementia'

country_codes = {'HRS': 1, 'ELSA': 2, 'LASI': 3, 'MHAS': 4, 'CHARLS': 5}
scale_col = 'scale'
country_col = 'country'

ckpt_path = "/content/drive/MyDrive/manuscript/5_weights/default_tabpfn-v2-classifier_weights.ckpt"
assert os.path.exists(ckpt_path), "Base model checkpoint not found. Please verify the path."

data_path = "/content/drive/MyDrive/manuscript/3_split_data/stacked_finetune.csv"
weights_output_path = "/content/drive/MyDrive/manuscript/5_weights/Finetuned_Weights"
os.makedirs(weights_output_path, exist_ok=True)
set
stacked_finetune = pd.read_csv(data_path)
print(f"Loaded fine-tuning data", flush=True)

# ========== Fine-tuning Parameters ==========
finetune_configurations = [
    {"n": 25, "batch_size": 10, "max_time": 3000, "learning_rate": 0.0001},
    {"n": 50, "batch_size": 10, "max_time": 5000, "learning_rate": 0.0001},
    {"n": 75, "batch_size": 10, "max_time": 7000, "learning_rate": 0.0001},
    {"n": "all", "batch_size": 10, "max_time": 9000, "learning_rate": 0.0001}
]

# ========== Fine-tuning Loop ==========
for config in finetune_configurations:

    target_percentage = config["n"]
    batch_size = config["batch_size"]
    max_time = config["max_time"]
    learning_rate = config["learning_rate"]

    print(f"\n{'='*80}", flush=True)
    print(f"Fine-tuning Configuration:", flush=True)
    if target_percentage == "all":
        print(f"Data usage: 100% (all data)", flush=True)
    else:
        print(f"Data usage: {target_percentage}%", flush=True)
    print(f"Batch size: {batch_size}", flush=True)
    print(f"Max training time: {max_time}s", flush=True)
    print(f"Learning rate: {learning_rate}", flush=True)
    print(f"{'='*80}", flush=True)

    if target_percentage == "all":
        multiclass_finetune_df = stacked_finetune.copy()
        percentage_label = "100pct"
    else:
        multiclass_finetune_list = []
        for country_code in country_codes.values():
            country_data = stacked_finetune[stacked_finetune[country_col] == country_code]
            for s in sorted(country_data[scale_col].unique()):
                scale_df = country_data[country_data[scale_col] == s]
                selected_part, _ = train_test_split(
                    scale_df,
                    test_size=(1 - (target_percentage / 100.0)),
                    stratify=scale_df[target_col],
                    random_state=42
                )
                multiclass_finetune_list.append(selected_part)
        multiclass_finetune_df = pd.concat(multiclass_finetune_list, ignore_index=True)
        percentage_label = f"{target_percentage}pct"

    # Stage 1: Binary classification fine-tuning (cognitive normal vs impaired)
    temp_binary_model_path = f"/tmp/binary_temp_{percentage_label}.ckpt"

    print("Stage 1: Binary classification fine-tuning...", flush=True)
    fine_tune_tabpfn(
        path_to_base_model=ckpt_path,
        save_path_to_fine_tuned_model=temp_binary_model_path,
        time_limit=max_time,
        finetuning_config={
            "learning_rate": learning_rate,
            "batch_size": batch_size
        },
        small_improvement_threshold=0.003,
        small_improvement_patience=25,
        validation_metric="log_loss",
        categorical_features_index=None,
        X_train=multiclass_finetune_df[predictors],
        y_train=multiclass_finetune_df[target_col],
        device="cuda",
        task_type="binary",
        show_training_curve=False,
        logger_level=1,
        random_seed=101
    )
    print(">>> Binary fine-tuning done", flush=True)

    # Stage 2: Three-class classification fine-tuning (initialised from binary weights)
    final_model_path = os.path.join(
        weights_output_path,
        f"tabpfn_finetuned_{percentage_label}_threeclass.ckpt"
    )

    print("Stage 2: Three-class classification fine-tuning...", flush=True)
    fine_tune_tabpfn(
        path_to_base_model=temp_binary_model_path,
        save_path_to_fine_tuned_model=final_model_path,
        time_limit=max_time,
        finetuning_config={
            "learning_rate": learning_rate,
            "batch_size": batch_size
        },
        small_improvement_threshold=0.003,
        small_improvement_patience=25,
        validation_metric="log_loss",
        categorical_features_index=None,
        X_train=multiclass_finetune_df[predictors],
        y_train=multiclass_finetune_df[target_col],
        device="cuda",
        task_type="multiclass",
        show_training_curve=False,
        logger_level=1,
        random_seed=101
    )
    print(">>> Three-class fine-tuning done", flush=True)
# Out:
# Writing /content/finetune_experiment.py

# %%
# !conda run --no-capture-output -n py311 python -u /content/finetune_experiment.py
# Out:
# Tue Aug 26 01:18:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             44W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Loaded fine-tuning data
#
# ================================================================================
# Fine-tuning Configuration:
# Data usage: 25%
# Batch size: 10
# Max training time: 3000s
# Learning rate: 0.0001
# ================================================================================
# Stage 1: Binary classification fine-tuning...
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Fine-tuning Train Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=2800, prevalence(MCI+Dementia)=0.150, Normal=0.850, MCI=0.125, Dementia=0.025
# Country 2 N=2464, prevalence(MCI+Dementia)=0.148, Normal=0.852, MCI=0.111, Dementia=0.037
# Country 3 N=2536, prevalence(MCI+Dementia)=0.563, Normal=0.437, MCI=0.381, Dementia=0.182
# Country 4 N=1872, prevalence(MCI+Dementia)=0.455, Normal=0.545, MCI=0.303, Dementia=0.152
#
# 🔍 [Fine-tuning Train Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [352, 352, 352, 352, 352, 352, 352]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1268, 1268]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [468, 468, 468, 468]
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Validation Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=714, prevalence(MCI+Dementia)=0.157, Normal=0.843, MCI=0.118, Dementia=0.039
# Country 2 N=623, prevalence(MCI+Dementia)=0.146, Normal=0.854, MCI=0.112, Dementia=0.034
# Country 3 N=634, prevalence(MCI+Dementia)=0.562, Normal=0.438, MCI=0.379, Dementia=0.183
# Country 4 N=472, prevalence(MCI+Dementia)=0.458, Normal=0.542, MCI=0.305, Dementia=0.153
#
# 🔍 [Validation Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [89, 89, 89, 89, 89, 89, 89]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [317, 317]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [118, 118, 118, 118]
#
# ✅ [Binary classification] Data splitting successful!
# Training set y-value counts:
# health_vs_mci_vs_dementia
# 0    6608
# 1    3064
# Name: count, dtype: int64
# Training set y-value proportions:
# health_vs_mci_vs_dementia
# 0    0.683209
# 1    0.316791
# Name: proportion, dtype: float64
# Validation set y-value counts:
# health_vs_mci_vs_dementia
# 0    1668
# 1     775
# Name: count, dtype: int64
# Validation set y-value proportions:
# health_vs_mci_vs_dementia
# 0    0.682767
# 1    0.317233
# Name: proportion, dtype: float64
#
# ✅ Final predictors for fine-tuning: ['asinmiss', 'logresvar', 'mdistance', 'gnorm', 'lz', 'u3', 'extreme', 'language'], total columns: 8
# Validation set proportion (test_size): 20.00%
# Fine-tuning Steps:   0% 38/10000 [02:13<10:04:12,  3.64s/it, Best Val. Loss=0.521, Best Val. Score=-0.521, Training Loss=0.519, Val. Loss=0.521, Patience=20, Time=2.86e+3, Utilization=100, Grad Norm=2.46][Early Stop] Validation loss improvement < 0.003 for 25 consecutive validations. Stopping...
# Fine-tuning Steps:   0% 38/10000 [02:17<10:17:46,  3.72s/it, Best Val. Loss=0.521, Best Val. Score=-0.521, Training Loss=0.519, Val. Loss=0.521, Patience=20, Time=2.86e+3, Utilization=100, Grad Norm=2.46]
# >>> Binary fine-tuning done
# Stage 2: Three-class classification fine-tuning...
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Fine-tuning Train Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=2800, prevalence(MCI+Dementia)=0.150, Normal=0.850, MCI=0.125, Dementia=0.025
# Country 2 N=2464, prevalence(MCI+Dementia)=0.148, Normal=0.852, MCI=0.111, Dementia=0.037
# Country 3 N=2536, prevalence(MCI+Dementia)=0.563, Normal=0.437, MCI=0.381, Dementia=0.182
# Country 4 N=1872, prevalence(MCI+Dementia)=0.455, Normal=0.545, MCI=0.303, Dementia=0.152
#
# 🔍 [Fine-tuning Train Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [352, 352, 352, 352, 352, 352, 352]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1268, 1268]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [468, 468, 468, 468]
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Validation Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=714, prevalence(MCI+Dementia)=0.157, Normal=0.843, MCI=0.118, Dementia=0.039
# Country 2 N=623, prevalence(MCI+Dementia)=0.146, Normal=0.854, MCI=0.112, Dementia=0.034
# Country 3 N=634, prevalence(MCI+Dementia)=0.562, Normal=0.438, MCI=0.379, Dementia=0.183
# Country 4 N=472, prevalence(MCI+Dementia)=0.458, Normal=0.542, MCI=0.305, Dementia=0.153
#
# 🔍 [Validation Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [89, 89, 89, 89, 89, 89, 89]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [317, 317]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [118, 118, 118, 118]
#
# ✅ Final predictors for fine-tuning: ['asinmiss', 'logresvar', 'mdistance', 'gnorm', 'lz', 'u3', 'extreme', 'language'], total columns: 8
# Validation set proportion (test_size): 20.00%
# Fine-tuning Steps:   0% 31/10000 [01:50<10:01:22,  3.62s/it, Best Val. Loss=0.712, Best Val. Score=-0.712, Training Loss=0.696, Val. Loss=0.714, Patience=14, Time=2.89e+3, Utilization=100, Grad Norm=0.274][Early Stop] Validation loss improvement < 0.003 for 25 consecutive validations. Stopping...
# Fine-tuning Steps:   0% 31/10000 [01:53<10:29:39,  3.79s/it, Best Val. Loss=0.712, Best Val. Score=-0.712, Training Loss=0.696, Val. Loss=0.714, Patience=14, Time=2.89e+3, Utilization=100, Grad Norm=0.274]
# >>> Three-class fine-tuning done
#
# ================================================================================
# Fine-tuning Configuration:
# Data usage: 50%
# Batch size: 10
# Max training time: 5000s
# Learning rate: 0.0001
# ================================================================================
# Stage 1: Binary classification fine-tuning...
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Fine-tuning Train Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=5628, prevalence(MCI+Dementia)=0.152, Normal=0.848, MCI=0.124, Dementia=0.027
# Country 2 N=4935, prevalence(MCI+Dementia)=0.149, Normal=0.851, MCI=0.112, Dementia=0.037
# Country 3 N=5072, prevalence(MCI+Dementia)=0.563, Normal=0.437, MCI=0.381, Dementia=0.182
# Country 4 N=3752, prevalence(MCI+Dementia)=0.455, Normal=0.545, MCI=0.303, Dementia=0.152
#
# 🔍 [Fine-tuning Train Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [402, 402, 402, 402, 402, 402, 402, 402, 402, 402, 402, 402, 402, 402]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [705, 705, 705, 705, 705, 705, 705]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [2536, 2536]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [938, 938, 938, 938]
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Validation Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=1414, prevalence(MCI+Dementia)=0.149, Normal=0.851, MCI=0.129, Dementia=0.020
# Country 2 N=1239, prevalence(MCI+Dementia)=0.147, Normal=0.853, MCI=0.113, Dementia=0.034
# Country 3 N=1268, prevalence(MCI+Dementia)=0.562, Normal=0.438, MCI=0.380, Dementia=0.181
# Country 4 N=940, prevalence(MCI+Dementia)=0.455, Normal=0.545, MCI=0.302, Dementia=0.153
#
# 🔍 [Validation Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [177, 177, 177, 177, 177, 177, 177]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [634, 634]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [235, 235, 235, 235]
#
# ✅ [Binary classification] Data splitting successful!
# Training set y-value counts:
# health_vs_mci_vs_dementia
# 0    13236
# 1     6151
# Name: count, dtype: int64
# Training set y-value proportions:
# health_vs_mci_vs_dementia
# 0    0.682726
# 1    0.317274
# Name: proportion, dtype: float64
# Validation set y-value counts:
# health_vs_mci_vs_dementia
# 0    3329
# 1    1532
# Name: count, dtype: int64
# Validation set y-value proportions:
# health_vs_mci_vs_dementia
# 0    0.684839
# 1    0.315161
# Name: proportion, dtype: float64
#
# ✅ Final predictors for fine-tuning: ['asinmiss', 'logresvar', 'mdistance', 'gnorm', 'lz', 'u3', 'extreme', 'language'], total columns: 8
# Validation set proportion (test_size): 20.00%
# Fine-tuning Steps:   0% 42/10000 [08:17<33:39:58, 12.17s/it, Best Val. Loss=0.524, Best Val. Score=-0.524, Training Loss=0.528, Val. Loss=0.524, Patience=20, Time=4.5e+3, Utilization=100, Grad Norm=1.56][Early Stop] Validation loss improvement < 0.003 for 25 consecutive validations. Stopping...
# Fine-tuning Steps:   0% 42/10000 [08:29<34:23:07, 12.43s/it, Best Val. Loss=0.524, Best Val. Score=-0.524, Training Loss=0.528, Val. Loss=0.524, Patience=20, Time=4.5e+3, Utilization=100, Grad Norm=1.56]
# >>> Binary fine-tuning done
# Stage 2: Three-class classification fine-tuning...
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Fine-tuning Train Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=5628, prevalence(MCI+Dementia)=0.152, Normal=0.848, MCI=0.124, Dementia=0.027
# Country 2 N=4935, prevalence(MCI+Dementia)=0.149, Normal=0.851, MCI=0.112, Dementia=0.037
# Country 3 N=5072, prevalence(MCI+Dementia)=0.563, Normal=0.437, MCI=0.381, Dementia=0.182
# Country 4 N=3752, prevalence(MCI+Dementia)=0.455, Normal=0.545, MCI=0.303, Dementia=0.152
#
# 🔍 [Fine-tuning Train Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [402, 402, 402, 402, 402, 402, 402, 402, 402, 402, 402, 402, 402, 402]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [705, 705, 705, 705, 705, 705, 705]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [2536, 2536]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [938, 938, 938, 938]
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Validation Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=1414, prevalence(MCI+Dementia)=0.149, Normal=0.851, MCI=0.129, Dementia=0.020
# Country 2 N=1239, prevalence(MCI+Dementia)=0.147, Normal=0.853, MCI=0.113, Dementia=0.034
# Country 3 N=1268, prevalence(MCI+Dementia)=0.562, Normal=0.438, MCI=0.380, Dementia=0.181
# Country 4 N=940, prevalence(MCI+Dementia)=0.455, Normal=0.545, MCI=0.302, Dementia=0.153
#
# 🔍 [Validation Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [177, 177, 177, 177, 177, 177, 177]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [634, 634]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [235, 235, 235, 235]
#
# ✅ Final predictors for fine-tuning: ['asinmiss', 'logresvar', 'mdistance', 'gnorm', 'lz', 'u3', 'extreme', 'language'], total columns: 8
# Validation set proportion (test_size): 20.00%
# Fine-tuning Steps:   0% 37/10000 [07:28<34:27:29, 12.45s/it, Best Val. Loss=0.713, Best Val. Score=-0.713, Training Loss=0.726, Val. Loss=0.716, Patience=0, Time=4.55e+3, Utilization=100, Grad Norm=5.06]
# >>> Three-class fine-tuning done
#
# ================================================================================
# Fine-tuning Configuration:
# Data usage: 75%
# Batch size: 10
# Max training time: 7000s
# Learning rate: 0.0001
# ================================================================================
# Stage 1: Binary classification fine-tuning...
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Fine-tuning Train Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=8442, prevalence(MCI+Dementia)=0.149, Normal=0.851, MCI=0.124, Dementia=0.025
# Country 2 N=7406, prevalence(MCI+Dementia)=0.148, Normal=0.852, MCI=0.112, Dementia=0.037
# Country 3 N=7608, prevalence(MCI+Dementia)=0.563, Normal=0.437, MCI=0.381, Dementia=0.182
# Country 4 N=5632, prevalence(MCI+Dementia)=0.456, Normal=0.544, MCI=0.303, Dementia=0.153
#
# 🔍 [Fine-tuning Train Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [603, 603, 603, 603, 603, 603, 603, 603, 603, 603, 603, 603, 603, 603]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1058, 1058, 1058, 1058, 1058, 1058, 1058]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [3804, 3804]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1408, 1408, 1408, 1408]
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Validation Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=2114, prevalence(MCI+Dementia)=0.152, Normal=0.848, MCI=0.126, Dementia=0.026
# Country 2 N=1855, prevalence(MCI+Dementia)=0.147, Normal=0.853, MCI=0.113, Dementia=0.034
# Country 3 N=1902, prevalence(MCI+Dementia)=0.563, Normal=0.437, MCI=0.381, Dementia=0.182
# Country 4 N=1408, prevalence(MCI+Dementia)=0.455, Normal=0.545, MCI=0.301, Dementia=0.153
#
# 🔍 [Validation Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [151, 151, 151, 151, 151, 151, 151, 151, 151, 151, 151, 151, 151, 151]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [265, 265, 265, 265, 265, 265, 265]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [951, 951]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [352, 352, 352, 352]
#
# ✅ [Binary classification] Data splitting successful!
# Training set y-value counts:
# health_vs_mci_vs_dementia
# 0    19881
# 1     9207
# Name: count, dtype: int64
# Training set y-value proportions:
# health_vs_mci_vs_dementia
# 0    0.683478
# 1    0.316522
# Name: proportion, dtype: float64
# Validation set y-value counts:
# health_vs_mci_vs_dementia
# 0    4974
# 1    2305
# Name: count, dtype: int64
# Validation set y-value proportions:
# health_vs_mci_vs_dementia
# 0    0.683336
# 1    0.316664
# Name: proportion, dtype: float64
#
# ✅ Final predictors for fine-tuning: ['asinmiss', 'logresvar', 'mdistance', 'gnorm', 'lz', 'u3', 'extreme', 'language'], total columns: 8
# Validation set proportion (test_size): 20.00%
# Fine-tuning Steps:   0% 36/10000 [14:57<70:56:18, 25.63s/it, Best Val. Loss=0.525, Best Val. Score=-0.525, Training Loss=0.521, Val. Loss=0.526, Patience=2, Time=6.1e+3, Utilization=100, Grad Norm=2.38][Early Stop] Validation loss improvement < 0.003 for 25 consecutive validations. Stopping...
# Fine-tuning Steps:   0% 36/10000 [15:23<72:59:52, 26.37s/it, Best Val. Loss=0.525, Best Val. Score=-0.525, Training Loss=0.521, Val. Loss=0.526, Patience=2, Time=6.1e+3, Utilization=100, Grad Norm=2.38]
# >>> Binary fine-tuning done
# Stage 2: Three-class classification fine-tuning...
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Fine-tuning Train Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=8442, prevalence(MCI+Dementia)=0.149, Normal=0.851, MCI=0.124, Dementia=0.025
# Country 2 N=7406, prevalence(MCI+Dementia)=0.148, Normal=0.852, MCI=0.112, Dementia=0.037
# Country 3 N=7608, prevalence(MCI+Dementia)=0.563, Normal=0.437, MCI=0.381, Dementia=0.182
# Country 4 N=5632, prevalence(MCI+Dementia)=0.456, Normal=0.544, MCI=0.303, Dementia=0.153
#
# 🔍 [Fine-tuning Train Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [603, 603, 603, 603, 603, 603, 603, 603, 603, 603, 603, 603, 603, 603]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1058, 1058, 1058, 1058, 1058, 1058, 1058]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [3804, 3804]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1408, 1408, 1408, 1408]
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Validation Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=2114, prevalence(MCI+Dementia)=0.152, Normal=0.848, MCI=0.126, Dementia=0.026
# Country 2 N=1855, prevalence(MCI+Dementia)=0.147, Normal=0.853, MCI=0.113, Dementia=0.034
# Country 3 N=1902, prevalence(MCI+Dementia)=0.563, Normal=0.437, MCI=0.381, Dementia=0.182
# Country 4 N=1408, prevalence(MCI+Dementia)=0.455, Normal=0.545, MCI=0.301, Dementia=0.153
#
# 🔍 [Validation Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [151, 151, 151, 151, 151, 151, 151, 151, 151, 151, 151, 151, 151, 151]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [265, 265, 265, 265, 265, 265, 265]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [951, 951]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [352, 352, 352, 352]
#
# ✅ Final predictors for fine-tuning: ['asinmiss', 'logresvar', 'mdistance', 'gnorm', 'lz', 'u3', 'extreme', 'language'], total columns: 8
# Validation set proportion (test_size): 20.00%
# Fine-tuning Steps:   0% 31/10000 [12:48<71:01:10, 25.65s/it, Best Val. Loss=0.71, Best Val. Score=-0.71, Training Loss=0.711, Val. Loss=0.711, Patience=11, Time=6.23e+3, Utilization=100, Grad Norm=1.06][Early Stop] Validation loss improvement < 0.003 for 25 consecutive validations. Stopping...
# Fine-tuning Steps:   0% 31/10000 [13:14<73:18:55, 26.48s/it, Best Val. Loss=0.71, Best Val. Score=-0.71, Training Loss=0.711, Val. Loss=0.711, Patience=11, Time=6.23e+3, Utilization=100, Grad Norm=1.06]
# >>> Three-class fine-tuning done
#
# ================================================================================
# Fine-tuning Configuration:
# Data usage: 100% (all data)
# Batch size: 10
# Max training time: 9000s
# Learning rate: 0.0001
# ================================================================================
# Stage 1: Binary classification fine-tuning...
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Fine-tuning Train Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=11256, prevalence(MCI+Dementia)=0.150, Normal=0.850, MCI=0.124, Dementia=0.026
# Country 2 N=9877, prevalence(MCI+Dementia)=0.148, Normal=0.852, MCI=0.112, Dementia=0.036
# Country 3 N=10144, prevalence(MCI+Dementia)=0.562, Normal=0.438, MCI=0.381, Dementia=0.182
# Country 4 N=7508, prevalence(MCI+Dementia)=0.456, Normal=0.544, MCI=0.303, Dementia=0.152
#
# 🔍 [Fine-tuning Train Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [804, 804, 804, 804, 804, 804, 804, 804, 804, 804, 804, 804, 804, 804]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1411, 1411, 1411, 1411, 1411, 1411, 1411]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [5072, 5072]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1877, 1877, 1877, 1877]
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Validation Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=2828, prevalence(MCI+Dementia)=0.149, Normal=0.851, MCI=0.124, Dementia=0.025
# Country 2 N=2471, prevalence(MCI+Dementia)=0.147, Normal=0.853, MCI=0.110, Dementia=0.037
# Country 3 N=2538, prevalence(MCI+Dementia)=0.563, Normal=0.437, MCI=0.381, Dementia=0.182
# Country 4 N=1880, prevalence(MCI+Dementia)=0.455, Normal=0.545, MCI=0.302, Dementia=0.153
#
# 🔍 [Validation Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [353, 353, 353, 353, 353, 353, 353]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1269, 1269]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [470, 470, 470, 470]
#
# ✅ [Binary classification] Data splitting successful!
# Training set y-value counts:
# health_vs_mci_vs_dementia
# 0    26502
# 1    12283
# Name: count, dtype: int64
# Training set y-value proportions:
# health_vs_mci_vs_dementia
# 0    0.683305
# 1    0.316695
# Name: proportion, dtype: float64
# Validation set y-value counts:
# health_vs_mci_vs_dementia
# 0    6649
# 1    3068
# Name: count, dtype: int64
# Validation set y-value proportions:
# health_vs_mci_vs_dementia
# 0    0.684265
# 1    0.315735
# Name: proportion, dtype: float64
#
# ✅ Final predictors for fine-tuning: ['asinmiss', 'logresvar', 'mdistance', 'gnorm', 'lz', 'u3', 'extreme', 'language'], total columns: 8
# Validation set proportion (test_size): 20.00%
# Fine-tuning Steps:   1% 56/10000 [43:28<130:58:58, 47.42s/it, Best Val. Loss=0.54, Best Val. Score=-0.54, Training Loss=0.655, Val. Loss=0.635, Patience=0, Time=6.39e+3, Utilization=100, Grad Norm=170]
# >>> Binary fine-tuning done
# Stage 2: Three-class classification fine-tuning...
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Fine-tuning Train Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=11256, prevalence(MCI+Dementia)=0.150, Normal=0.850, MCI=0.124, Dementia=0.026
# Country 2 N=9877, prevalence(MCI+Dementia)=0.148, Normal=0.852, MCI=0.112, Dementia=0.036
# Country 3 N=10144, prevalence(MCI+Dementia)=0.562, Normal=0.438, MCI=0.381, Dementia=0.182
# Country 4 N=7508, prevalence(MCI+Dementia)=0.456, Normal=0.544, MCI=0.303, Dementia=0.152
#
# 🔍 [Fine-tuning Train Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [804, 804, 804, 804, 804, 804, 804, 804, 804, 804, 804, 804, 804, 804]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1411, 1411, 1411, 1411, 1411, 1411, 1411]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [5072, 5072]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1877, 1877, 1877, 1877]
#
# === 🚩 Final Consistency Check for Fine-tuning Dataset 🚩 ===
#
# 📊 [Validation Set] Sample Counts and Prevalence by Country (3-class):
# Country 1 N=2828, prevalence(MCI+Dementia)=0.149, Normal=0.851, MCI=0.124, Dementia=0.025
# Country 2 N=2471, prevalence(MCI+Dementia)=0.147, Normal=0.853, MCI=0.110, Dementia=0.037
# Country 3 N=2538, prevalence(MCI+Dementia)=0.563, Normal=0.437, MCI=0.381, Dementia=0.182
# Country 4 N=1880, prevalence(MCI+Dementia)=0.455, Normal=0.545, MCI=0.302, Dementia=0.153
#
# 🔍 [Validation Set] ID/Count Consistency Checks Across Scales:
# Country 1: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202]
# Country 2: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [353, 353, 353, 353, 353, 353, 353]
# Country 3: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [1269, 1269]
# Country 4: ID consistency across scales: ✅ | Count consistency: ✅ | Counts per scale: [470, 470, 470, 470]
#
# ✅ Final predictors for fine-tuning: ['asinmiss', 'logresvar', 'mdistance', 'gnorm', 'lz', 'u3', 'extreme', 'language'], total columns: 8
# Validation set proportion (test_size): 20.00%
# Fine-tuning Steps:   0% 46/10000 [35:03<129:23:45, 46.80s/it, Best Val. Loss=0.722, Best Val. Score=-0.722, Training Loss=0.725, Val. Loss=0.723, Patience=16, Time=6.89e+3, Utilization=100, Grad Norm=2.56][Early Stop] Validation loss improvement < 0.003 for 25 consecutive validations. Stopping...
# Fine-tuning Steps:   0% 46/10000 [35:50<132:08:18, 47.79s/it, Best Val. Loss=0.722, Best Val. Score=-0.722, Training Loss=0.725, Val. Loss=0.723, Patience=16, Time=6.89e+3, Utilization=100, Grad Norm=2.56]
# >>> Three-class fine-tuning done
